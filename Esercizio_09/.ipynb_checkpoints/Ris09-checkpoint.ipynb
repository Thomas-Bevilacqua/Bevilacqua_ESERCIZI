# %% [markdown]
# ## Esercizio 09
#
# Per risolvere l'esercizio ho scritto un file 'Genetic' contenente tutte le funzioni necessarie al funzionamento di un algoritmo genetico. Oltre alle varie funzioni per stampare i risultati ho implementato:
# - una funzione per generare città distribuite lungo una circonferenza;
# - una funzione per calcolare le distanze (ho usato la $L^{(2)}$ indicata nel testo);
# - quattro mutazioni: scambio di due città, shift di un certo numero di città a partire da una data posizione, scambio di un gruppo di città e inversione di ordine. Vengono chiamate tramite la funzione 'Make_Mutation' che ne estrae una con un probabilità del 10%; i parametri necessari al funzionamento delle singole mutazioni vengono estratti casualmente e nessuna modifica mai l'hometown;
# - una funzione di crossover come indicata nel testo (il crossover avviene con il 50% di probabilità);
# - infine una funzione 'Sons' che crea una nuova generazione nel seguente modo: valuta la lunghezza del percorso per ogni individuo e ordina dal migliore al peggiore; estrae una posizione (nella prima metà, cioè tra i migliori) usando il secondo operatore selection riportato nel testo (ho usato come esponente 2) fino a creare un insieme di buoni genitori; estrae casualmente due genitori, fa il crossover e delle mutazioni fino a creare una nuova popolazione.

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
def Circle(x, y, r):
    return x**2 + y**2 - r

def L2(xi, yi, xf, yf):
    return (xf - xi)**2 + (yf - yi)**2

# %%
N = 100
r = 1.

# Construct the circle
xx = np.linspace(-r, r, N)
yy = np.linspace(-r, r, N)
X, Y = np.meshgrid(xx, yy)

plt.rc('text', usetex=True)
plt.figure(figsize=(8, 8))

plt.title('Cities disposition')
x, y = np.loadtxt("circ.0", usecols=(0,1), unpack='true')
plt.plot(x, y, linestyle=' ', marker='.', label='Cities')
plt.plot(x[0], y[0], linestyle=' ', marker='.', color='red', label='Hometown')
plt.contour(X, Y, Circle(X, Y, r), [0], linewidths=0.5, colors='black')

plt.xlabel('$x$')
plt.ylabel('$y$')
plt.xlim(-1.2, 1.2)
plt.ylim(-1.2, 1.2)
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# Quella in figura è la disposizione di 30 città utilizzata. A partire dalla hometown il percorso più breve si costruisce andando di volta in volta nella città più vicina: in questo caso mi aspetto un percorso di spezzate in senso antiorario.

# %% [markdown]
# Per la simulazione ho scelto i seguenti parametri:
# - numero di mutazioni: 14,
# - numero di generazioni: 2000,
# - popolazione: 1000.
#
# Ho scelto questi parametri dopo qualche prova, in modo da avere una popolazione abbastanza variegata. 2000 generazioni sono sufficienti dato che la lunghezza è già stabile e tale rimane (dato che è proprio quella minima).
#
# La simulazione quindi procede così:
# - vengono estratte le città controllando non ci siano ripetizioni;
# - viene generata la popolazione facendo mutare (1000 mutazioni) la popolazione originale;
# - vengono create le nuove generazioni, stampando su file la lunghezza del percorso migliore ("L2.shortest") e la lunghezza media del percorso per la miglior metà della popolazione ("length.ave");
# - viene stampato il percorso migliore ("config.fin").
#
# Si ottengono i seguenti risultati (per chiarezza non ho riportato le deviazioni standard nel primo grafico):

# %%
# Compute the optimized path length
xc, yc = np.loadtxt("circ.fin", usecols=(0,1), unpack='true')
ngen = 2000
dim = np.size(xc)
sum = 0.

for i in range(dim - 1):   # the last city is the first
    sum += L2(xc[i], yc[i], xc[i+1], yc[i+1])

print('Optimized configuration path length = ', sum)
# Out:
# Optimized configuration path length =  3.3267205764689596

# %%
plt.figure(figsize=(16,16))
plt.suptitle('Cities on a circle',fontsize=20)

plt.subplot(221)
plt.title('Average path length')
x, y= np.loadtxt("circ.ave", usecols=(0,1), unpack='true')
plt.plot(x, y)

plt.xlabel('Generation')
plt.ylabel('$<L^{(2)}>$')
plt.grid(True)

plt.subplot(222)
plt.title('Best path length')
x, y= np.loadtxt("circ.shortest", usecols=(0,1), unpack='true')
plt.plot(x, y, label='Data')
plt.axhline(y=sum, color='red', linewidth=0.7, label='Expected')

plt.xlabel('Generation')
plt.ylabel('$L^{(2)}_{best}$')
plt.grid(True)
plt.legend()

plt.subplot(223)
plt.title('Shortest path')
plt.plot(xc, yc, marker='.')
plt.plot(xc[0], yc[0], linestyle=' ', marker='.', color='red', label='Hometown')
plt.contour(X, Y, Circle(X, Y, r), [0], linewidths=0.5, colors='black')

plt.xlabel('$x$')
plt.ylabel('$y$')
plt.xlim(-1.2, 1.2)
plt.ylim(-1.2, 1.2)
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# Ripeto la simulazione con le città in un quadrato.

# %%
l = 1.

plt.rc('text', usetex=True)
plt.figure(figsize=(8, 8))

plt.title('Cities disposition')
x, y = np.loadtxt("sq.0", usecols=(0,1), unpack='true')
plt.plot(x, y, linestyle=' ', marker='.', label='Cities')
plt.plot(x[0], y[0], linestyle=' ', marker='.', color='red', label='Hometown')

plt.axhline(y=-l, xmin=-l, xmax=l, color='black', linewidth=0.5)
plt.axhline(y=l, xmin=-l, xmax=l, color='black', linewidth=0.5)
plt.axvline(x=-l, ymin=-l, ymax=l, color='black', linewidth=0.5)
plt.axvline(x=l, ymin=-l, ymax=l, color='black', linewidth=0.5)

plt.xlabel('$x$')
plt.ylabel('$y$')
plt.xlim(-1.2, 1.2)
plt.ylim(-1.2, 1.2)
plt.grid(True)
plt.legend()

plt.show()

# %%
# Compute the optimized path length
xb, yb = np.loadtxt("sq.fin", usecols=(0,1), unpack='true')
ngen = 2000
dim = np.size(xb)
sum = 0.

for i in range(dim - 1):   # the last city is the first
    sum += L2(xb[i], yb[i], xb[i+1], yb[i+1])

print('Optimized configuration path length = ', sum)
# Out:
# Optimized configuration path length =  3.8624747412787896

# %%
plt.figure(figsize=(16,16))
plt.suptitle('Cities in a square',fontsize=20)

plt.subplot(221)
plt.title('Average path length')
x, y= np.loadtxt("sq.ave", usecols=(0,1), unpack='true')
plt.plot(x, y)

plt.xlabel('Generation')
plt.ylabel('$<L^{(2)}>$')
plt.grid(True)

plt.subplot(222)
plt.title('Best path length')
x, y= np.loadtxt("sq.shortest", usecols=(0,1), unpack='true')
plt.plot(x, y, label='Data')
plt.axhline(y=sum, color='red', linewidth=0.7, label='Expected')

plt.xlabel('Generation')
plt.ylabel('$L^{(2)}_{best}$')
plt.grid(True)
plt.legend()

plt.subplot(223)
plt.title('Shortest path')
plt.plot(xb, yb, marker='.')
plt.plot(xb[0], yb[0], linestyle=' ', marker='.', color='red', label='Hometown')
plt.axhline(y=-l, xmin=-l, xmax=l, color='black', linewidth=0.5)
plt.axhline(y=l, xmin=-l, xmax=l, color='black', linewidth=0.5)
plt.axvline(x=-l, ymin=-l, ymax=l, color='black', linewidth=0.5)
plt.axvline(x=l, ymin=-l, ymax=l, color='black', linewidth=0.5)

plt.xlabel('$x$')
plt.ylabel('$y$')
plt.xlim(-1.2, 1.2)
plt.ylim(-1.2, 1.2)
plt.grid(True)
plt.legend()

plt.show()
