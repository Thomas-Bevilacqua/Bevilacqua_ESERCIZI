# %% [markdown]
# ## Esercizio 11
#
# Ho fatto questo esercizio utilizzando i codici forniti nel testo.

# %% [markdown]
# ### Parte 01
#
# Provo per prima cosa a modificare i parametri suggeriti in modo da capire come varia il risultato nel caso della regressione lineare.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import tensorflow as tf

from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %% [markdown]
# Per prima cosa osservo come variano i dati di input all'aumentare del rumore: mi aspetto una deviazione dal comportamento ideale. Vengono riportati alcuni casi nelle prossime figure.

# %%
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 100)
x_valid = np.random.uniform(-1, 1, 10)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

# %%
# plot training and target dataset
plt.rc('text', usetex=True)

plt.figure(figsize=(16,12))
plt.suptitle('Increasing noise',fontsize=20)

plt.subplot(221)
plt.title('$\sigma = 0.01$')
sigma = 0.01
y_valid = np.random.normal(m * x_valid + b, sigma)

plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

plt.subplot(222)
plt.title('$\sigma = 0.02$')
sigma = 0.02
y_valid = np.random.normal(m * x_valid + b, sigma)

plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

plt.subplot(223)
plt.title('$\sigma = 0.05$')
sigma = 0.05
y_valid = np.random.normal(m * x_valid + b, sigma)

plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

plt.subplot(224)
plt.title('$\sigma = 0.1$')
sigma = 0.1
y_valid = np.random.normal(m * x_valid + b, sigma)

plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

plt.show()

# %% [markdown]
# Alleno il modello creato utilizzando le coppie $(x,y_{train})$ da cui 'optimizer' troverà i migliori pesi per minimizzare la funzione MSE. Faccio un po' di tentativi al variare dei parametri $\sigma$, $N_{epoch}$ e $N_{train}$. I risultati proposti sono ottenuti utilizzando i seguenti parametri:

# %%
sigma = 0.03 # noise standard deviation
ep = 70
n_tr = 9000
n_val = 1000

x_train = np.random.uniform(-1, 1, 100)
x_valid = np.random.uniform(-1, 1, 10)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.0 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# compose the NN model
test = tf.keras.Sequential()
test.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
test.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
test.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model using training dataset
# over n epochs of N batch size each
# report training progress against validation data
history = test.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=ep,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 100 samples, validate on 10 samples
# Epoch 1/70
# 100/100 [==============================] - 0s 968us/sample - loss: 3.5919 - mean_squared_error: 3.5919 - val_loss: 3.2951 - val_mean_squared_error: 3.2951
# Epoch 2/70
# 100/100 [==============================] - 0s 94us/sample - loss: 3.3623 - mean_squared_error: 3.3623 - val_loss: 3.1274 - val_mean_squared_error: 3.1274
# Epoch 3/70
# 100/100 [==============================] - 0s 131us/sample - loss: 3.1674 - mean_squared_error: 3.1674 - val_loss: 2.9184 - val_mean_squared_error: 2.9184
# Epoch 4/70
# 100/100 [==============================] - 0s 127us/sample - loss: 2.9224 - mean_squared_error: 2.9224 - val_loss: 2.7241 - val_mean_squared_error: 2.7241
# Epoch 5/70
# 100/100 [==============================] - 0s 104us/sample - loss: 2.7060 - mean_squared_error: 2.7060 - val_loss: 2.5717 - val_mean_squared_error: 2.5717
# Epoch 6/70
# 100/100 [==============================] - 0s 154us/sample - loss: 2.5328 - mean_squared_error: 2.5328 - val_loss: 2.4422 - val_mean_squared_error: 2.4422
# Epoch 7/70
# 100/100 [==============================] - 0s 136us/sample - loss: 2.3965 - mean_squared_error: 2.3965 - val_loss: 2.3100 - val_mean_squared_error: 2.3100
# Epoch 8/70
# 100/100 [==============================] - 0s 145us/sample - loss: 2.2494 - mean_squared_error: 2.2494 - val_loss: 2.1636 - val_mean_squared_error: 2.1636
# Epoch 9/70
# 100/100 [==============================] - 0s 130us/sample - loss: 2.0853 - mean_squared_error: 2.0853 - val_loss: 2.0541 - val_mean_squared_error: 2.0541
# Epoch 10/70
# 100/100 [==============================] - 0s 159us/sample - loss: 1.9743 - mean_squared_error: 1.9743 - val_loss: 1.9211 - val_mean_squared_error: 1.9211
# Epoch 11/70
# 100/100 [==============================] - 0s 155us/sample - loss: 1.8227 - mean_squared_error: 1.8227 - val_loss: 1.8172 - val_mean_squared_error: 1.8172
# Epoch 12/70
# 100/100 [==============================] - 0s 140us/sample - loss: 1.7222 - mean_squared_error: 1.7222 - val_loss: 1.7276 - val_mean_squared_error: 1.7276
# Epoch 13/70
# 100/100 [==============================] - 0s 128us/sample - loss: 1.6290 - mean_squared_error: 1.6290 - val_loss: 1.6293 - val_mean_squared_error: 1.6293
# Epoch 14/70
# 100/100 [==============================] - 0s 216us/sample - loss: 1.5277 - mean_squared_error: 1.5277 - val_loss: 1.5322 - val_mean_squared_error: 1.5322
# Epoch 15/70
# 100/100 [==============================] - 0s 226us/sample - loss: 1.4190 - mean_squared_error: 1.4190 - val_loss: 1.4361 - val_mean_squared_error: 1.4361
# Epoch 16/70
# 100/100 [==============================] - 0s 103us/sample - loss: 1.3187 - mean_squared_error: 1.3187 - val_loss: 1.3599 - val_mean_squared_error: 1.3599
# Epoch 17/70
# 100/100 [==============================] - 0s 212us/sample - loss: 1.2529 - mean_squared_error: 1.2529 - val_loss: 1.3002 - val_mean_squared_error: 1.3002
# Epoch 18/70
# 100/100 [==============================] - 0s 187us/sample - loss: 1.1902 - mean_squared_error: 1.1902 - val_loss: 1.2446 - val_mean_squared_error: 1.2446
# Epoch 19/70
# 100/100 [==============================] - 0s 129us/sample - loss: 1.1328 - mean_squared_error: 1.1328 - val_loss: 1.1745 - val_mean_squared_error: 1.1745
# Epoch 20/70
# 100/100 [==============================] - 0s 136us/sample - loss: 1.0607 - mean_squared_error: 1.0607 - val_loss: 1.1213 - val_mean_squared_error: 1.1213
# Epoch 21/70
# 100/100 [==============================] - 0s 156us/sample - loss: 1.0084 - mean_squared_error: 1.0084 - val_loss: 1.0698 - val_mean_squared_error: 1.0698
# Epoch 22/70
# 100/100 [==============================] - 0s 96us/sample - loss: 0.9579 - mean_squared_error: 0.9579 - val_loss: 1.0201 - val_mean_squared_error: 1.0201
# Epoch 23/70
# 100/100 [==============================] - 0s 203us/sample - loss: 0.9109 - mean_squared_error: 0.9109 - val_loss: 0.9587 - val_mean_squared_error: 0.9587
# Epoch 24/70
# 100/100 [==============================] - 0s 131us/sample - loss: 0.8520 - mean_squared_error: 0.8520 - val_loss: 0.9071 - val_mean_squared_error: 0.9071
# Epoch 25/70
# 100/100 [==============================] - 0s 159us/sample - loss: 0.8045 - mean_squared_error: 0.8045 - val_loss: 0.8576 - val_mean_squared_error: 0.8576
# Epoch 26/70
# 100/100 [==============================] - 0s 140us/sample - loss: 0.7556 - mean_squared_error: 0.7556 - val_loss: 0.8192 - val_mean_squared_error: 0.8192
# Epoch 27/70
# 100/100 [==============================] - 0s 197us/sample - loss: 0.7196 - mean_squared_error: 0.7196 - val_loss: 0.7753 - val_mean_squared_error: 0.7753
# Epoch 28/70
loss: 0.0977 - mean_squared_error: 0.0977 - val_loss: 0.1076 - val_mean_squared_error: 0.1076
# Epoch 66/70
# 100/100 [==============================] - 0s 92us/sample - loss: 0.0923 - mean_squared_error: 0.0923 - val_loss: 0.1028 - val_mean_squared_error: 0.1028
# Epoch 67/70
# 100/100 [==============================] - 0s 89us/sample - loss: 0.0883 - mean_squared_error: 0.0883 - val_loss: 0.0983 - val_mean_squared_error: 0.0983
# Epoch 68/70
# 100/100 [==============================] - 0s 80us/sample - loss: 0.0842 - mean_squared_error: 0.0842 - val_loss: 0.0928 - val_mean_squared_error: 0.0928
# Epoch 69/70
# 100/100 [==============================] - 0s 91us/sample - loss: 0.0800 - mean_squared_error: 0.0800 - val_loss: 0.0890 - val_mean_squared_error: 0.0890
# Epoch 70/70
# 100/100 [==============================] - 0s 104us/sample - loss: 0.0765 - mean_squared_error: 0.0765 - val_loss: 0.0846 - val_mean_squared_error: 0.0846

# %%
# evaluate model
print('MODEL TEST:')
score = test.evaluate(x_valid, y_valid, batch_size=32, verbose=1)
# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print()
print()

# evaluate model with the exact curve
print('MODEL TEST WITH THE EXACT CURVE:')
score = test.evaluate(x_valid, y_target, batch_size=32, verbose=1)
# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# MODEL TEST:
# 10/10 [==============================] - 0s 205us/sample - loss: 0.0846 - mean_squared_error: 0.0846
#
# Test loss: 0.08462844043970108
# Test accuracy: 0.08462844
#
#
# MODEL TEST WITH THE EXACT CURVE:
# 10/10 [==============================] - 0s 89us/sample - loss: 0.0846 - mean_squared_error: 0.0846
#
# Test loss: 0.08462844043970108
# Test accuracy: 0.08462844

# %%
# look into training history
# Plot training & validation loss values
plt.figure(figsize=(14,6))
plt.suptitle('Example',fontsize=20)

plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')

plt.subplot(122)
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = test.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r', label='Predicted')
plt.plot(x_valid, y_target, label='Validation data')
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# Osservo che nei vari tentativi, fissato il rumore, se si aumentano $N_{epoch}$ e $N_{train}$ i risultati migliorano. Aumentando il rumore è necessario incrementare notevolmente gli altri parametri affinché si abbia una buona predizione da parte della NN: naturalmente bisogna prestare attenzione a non incorrere nell'overfitting.

# %% [markdown]
# ### Parte 02
#
# Ripeto tutto con il polinomio fornito; utilizzo un numero abbastanza elevato per i punti di train e validation. Ho deciso di mettere a zero il rumore dei dati per semplicità.

# %%
# Number of train and validation points
N_tr = 9000
N_val = 1000

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, N_tr)
x_valid = np.random.uniform(-1, 1, N_val)
x_valid.sort()

y_target = 4. - 3.*x_valid - 2.*x_valid**2 + 3.*x_valid**3 # ideal (target) polinomial

sigma = 0.0 # put to zero the noise
y_train = np.random.normal(4. - 3.*x_train - 2.*x_train**2 + 3.*x_train**3, sigma)
y_valid = np.random.normal(4. - 3.*x_valid - 2.*x_valid**2 + 3.*x_valid**3, sigma)

# %% [markdown]
# Scelgo un neurone in input e uno in output dato che la funzione da fittare è a una variabile e a valori reali. Inserisco poi una serie di hidden layer per riprodurre i picchi della funzione.
#
# Per prima cosa parto dai dati usati nella parte precedente, fissando come funzione di attivazione 'sigmoid' e variando il numero di hidden layers e di neuroni, in modo da avere un'idea di come si comporti l'algoritmo. Riporto ora alcune immagini dei risultati, realizzate con l'algoritmo che riporto in seguito (le varie funzioni provate le ho prese dal sito di riferimento di 'Keras')
#
# #### Primo tentativo: 1 hidden layer da 20 neuroni
# <img src="First.png">
#
# Noto una minima somiglianza con la curva ma non coincidono assolutamente: aumentando il numero di neuroni il risultato non cambia molto e dunque decido di utilizzare un altro hidden layer.
#
# #### Secondo tentativo: 2 hidden layer da 30 neuroni
# <img src="Second.png">
#
# Si vede un peggioramento del risultato e anche aumentando il numero di neuroni la qualità del fit non migliora. Provo allora a cambiare le funzioni di attivazione.
#
# #### Terzo tentativo: funzione di attivazione 'elu' per entrambi gli hidden layers
# <img src="Third.png">
#
# Osservo un sensibile miglioramento nella regione $x<0.5$ mentre la coda sulla destra non è molto ben fittata. Di nuovo, anche se si aumentano il numero di neuroni il risultato non cambia molto. Anche provando a mescolare le varie funzioni di attivazione non si hanno sensibili miglioramenti. Per questo decido di mantenere come funzioni di attivazione 'elu' e provo a modificare la funzione di ottimizzazione.
#
# #### Quarto tentativo: funzione di ottimizzazione 'Adam'
# <img src="Fourth.png">
#
# Scegliendo questa funzione di ottimizzazione il risultato migliora notevolmente, infatti i punti fittano bene anche la coda. Provo dunque a modificare anche la funzione di loss per vedere se cambia qualcosa.
#
# #### Quinto tentativo: loss function 'mae'
# <img src="Fifth.png">
#
# Dato che il fit avviene per una funzione continua, provo ad utilizzare come loss function 'mae' (mean absolute error): tuttavia si vede che quella usata finora, la 'mse' (mean squared error) funziona meglio.
#
# Dunque nelle prossime celle viene riportato il codice utilizzato per realizzare la figura del punto 4 che pare essere la migliore tra tutte.

# %%
# compose the NN model
model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))
model.add(Dense(20, Activation('elu')))
model.add(Dense(30, Activation('elu')))
model.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='Adam', loss='mse', metrics=['mse'])

# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 1)                 2
# _________________________________________________________________
# dense_8 (Dense)              (None, 20)                40
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                630
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 703
# Trainable params: 703
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model using training dataset
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/50
# 9000/9000 [==============================] - 0s 48us/sample - loss: 2.6389 - mean_squared_error: 2.6389 - val_loss: 0.4652 - val_mean_squared_error: 0.4652
# Epoch 2/50
# 9000/9000 [==============================] - 0s 36us/sample - loss: 0.3237 - mean_squared_error: 0.3237 - val_loss: 0.1819 - val_mean_squared_error: 0.1819
# Epoch 3/50
# 9000/9000 [==============================] - 0s 54us/sample - loss: 0.1484 - mean_squared_error: 0.1484 - val_loss: 0.1133 - val_mean_squared_error: 0.1133
# Epoch 4/50
# 9000/9000 [==============================] - 0s 50us/sample - loss: 0.0822 - mean_squared_error: 0.0822 - val_loss: 0.0556 - val_mean_squared_error: 0.0556
# Epoch 5/50
# 9000/9000 [==============================] - 0s 41us/sample - loss: 0.0400 - mean_squared_error: 0.0400 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 6/50
# 9000/9000 [==============================] - 0s 39us/sample - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 7/50
# 9000/9000 [==============================] - 0s 37us/sample - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# Epoch 8/50
# 9000/9000 [==============================] - 0s 35us/sample - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 9/50
# 9000/9000 [==============================] - 0s 37us/sample - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# Epoch 10/50
# 9000/9000 [==============================] - 0s 37us/sample - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 11/50
# 9000/9000 [==============================] - 0s 47us/sample - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 12/50
# 9000/9000 [==============================] - 0s 50us/sample - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 13/50
# 9000/9000 [==============================] - 0s 39us/sample - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0078 - val_mean_squared_error: 0.0078
# Epoch 14/50
# 9000/9000 [==============================] - 0s 41us/sample - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 15/50
# 9000/9000 [==============================] - 0s 40us/sample - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 16/50
# 9000/9000 [==============================] - 0s 52us/sample - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 17/50
# 9000/9000 [==============================] - 0s 44us/sample - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 18/50
# 9000/9000 [==============================] - 0s 47us/sample - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 19/50
# 9000/9000 [==============================] - 0s 39us/sample - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 20/50
# 9000/9000 [==============================] - 0s 39us/sample - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 21/50
# 9000/9000 [==============================] - 0s 39us/sample - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 22/50
# 9000/9000 [==============================] - 0s 39us/sample - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 23/50
# 9000/9000 [==============================] - 0s 40us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 24/50
# 9000/9000 [==============================] - 0s 41us/sample - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 25/50
# 9000/9000 [==============================] - 0s 40us/sample - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 26/50
# 9000/9000 [==============================] - 0s 40us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 27/50
# 9000/9000 [==============================] - 0s 40us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 28/50
# 9000/9000 [==============================] - 0s 41us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 29/50
# 9000/9000 [==============================] - 0s 41us/sample - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 30/50
# 9000/9000 [==============================] - 0s 48us/sample - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 31/50
# 9000/9000 [==============================] - 0s 46us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 32/50
# 9000/9000 [==============================] - 0s 41us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 33/50
# 9000/9000 [==============================] - 0s 40us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 8.7798e-04 - val_mean_squared_error: 8.7798e-04
# Epoch 34/50
# 9000/9000 [==============================] - 0s 41us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss:
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)
# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print()
print()

# evaluate model with the exact curve
print('MODEL TEST WITH THE EXACT CURVE:')
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)
# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# MODEL TEST:
# 1000/1000 [==============================] - 0s 15us/sample - loss: 5.9156e-04 - mean_squared_error: 5.9156e-04
#
# Test loss: 0.0005915575725593953
# Test accuracy: 0.00059155765
#
#
# MODEL TEST WITH THE EXACT CURVE:
# 1000/1000 [==============================] - 0s 14us/sample - loss: 5.9156e-04 - mean_squared_error: 5.9156e-04
#
# Test loss: 0.0005915575725593953
# Test accuracy: 0.00059155765

# %%
# look into training history
# Plot training & validation loss values
plt.figure(figsize=(14,6))
plt.suptitle('Best try',fontsize=20)

plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')

plt.subplot(122)
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r', label='Predicted')
plt.plot(x_valid, y_target, label='Validation data')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# Con questa scelta dei parametri, provo a vedere come va il fit al di fuori dell'intervallo di training.

# %%
plt.figure(figsize=(10,5))
plt.title('NN prevision in $[-1.5;1.5]$ using the best parameters')

# Plot the polinomial in [-1.5, 1.5]
x_valid = np.random.uniform(-1.5, 1.5, 200)
x_valid.sort()
y_target = 4. - 3.*x_valid - 2.*x_valid**2 + 3.*x_valid**3

plt.plot(x_valid, y_target, label='Expected')

# Plot the prevision
x_predicted = np.random.uniform(-1.5, 1.5, 200)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r', label='Predicted')

plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Noto che nel range di training il fit è ottimo mentre basta allontanarsi pochissimo dai bordi affinché l'abilità predittiva della NN svanisca.

# %% [markdown]
# ### Parte 03
#
# Per risolvere quest'ultima parte prendo come punto di partenza i parametri utilizzati nel punto precedente e vedo come si comporta la NN; successivamente modifico i parametri come fatto prima per trovare la miglior configurazione. Di nuovo metto a zero il rumore per semplicità.

# %%
# Function (takes a vector gives a scalar)
def Sin(x):
    return np.sin( x[:,0]**2 + x[:,1]**2 )

# %%
# Number of train and validation points
#N_tr = 45000
#N_val = 5000

# Define some vectors
x_train = np.zeros((9000, 2))
x_valid = np.zeros((1000, 2))

# generate training inputs
np.random.seed(0)
x_train[:,0] = np.random.uniform(-1.5, 1.5, 9000)
x_train[:,1] = np.random.uniform(-1.5, 1.5, 9000)

x_valid[:,0] = np.random.uniform(-1.5, 1.5, 1000)
x_valid[:,1] = np.random.uniform(-1.5, 1.5, 1000)

x_valid[0].sort()
x_valid[0].sort()

y_target = Sin(x_valid)

sigma = 0.0 # put to zero the noise
y_train = np.random.normal(Sin(x_train), sigma)
y_valid = np.random.normal(Sin(x_valid), sigma)

# %% [markdown]
# Rispetto a prima modifico il primo layer includendo due neuroni dato che ho due variabili in input.

# %%
# compose the NN model
model = tf.keras.Sequential()
model.add(Dense(2, input_shape=(2,)))
model.add(Dense(40, Activation('sigmoid')))
model.add(Dense(50, Activation('elu')))
model.add(Dense(20, Activation('elu')))
model.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='Adam', loss='mse', metrics=['mse'])

# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_81 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_82 (Dense)             (None, 40)                120
# _________________________________________________________________
# dense_83 (Dense)             (None, 50)                2050
# _________________________________________________________________
# dense_84 (Dense)             (None, 20)                1020
# _________________________________________________________________
# dense_85 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 3,217
# Trainable params: 3,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model using training dataset
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/50
# 9000/9000 [==============================] - 1s 104us/sample - loss: 0.1590 - mean_squared_error: 0.1590 - val_loss: 0.1681 - val_mean_squared_error: 0.1681
# Epoch 2/50
# 9000/9000 [==============================] - 0s 53us/sample - loss: 0.1562 - mean_squared_error: 0.1562 - val_loss: 0.1613 - val_mean_squared_error: 0.1613
# Epoch 3/50
# 9000/9000 [==============================] - 0s 54us/sample - loss: 0.1559 - mean_squared_error: 0.1559 - val_loss: 0.1616 - val_mean_squared_error: 0.1616
# Epoch 4/50
# 9000/9000 [==============================] - 0s 54us/sample - loss: 0.1546 - mean_squared_error: 0.1546 - val_loss: 0.1754 - val_mean_squared_error: 0.1754
# Epoch 5/50
# 9000/9000 [==============================] - 0s 53us/sample - loss: 0.1566 - mean_squared_error: 0.1566 - val_loss: 0.1685 - val_mean_squared_error: 0.1685
# Epoch 6/50
# 9000/9000 [==============================] - 1s 56us/sample - loss: 0.1547 - mean_squared_error: 0.1547 - val_loss: 0.1604 - val_mean_squared_error: 0.1604
# Epoch 7/50
# 9000/9000 [==============================] - 1s 56us/sample - loss: 0.1535 - mean_squared_error: 0.1535 - val_loss: 0.1597 - val_mean_squared_error: 0.1597
# Epoch 8/50
# 9000/9000 [==============================] - 1s 56us/sample - loss: 0.1550 - mean_squared_error: 0.1550 - val_loss: 0.1596 - val_mean_squared_error: 0.1596
# Epoch 9/50
# 9000/9000 [==============================] - 1s 56us/sample - loss: 0.1535 - mean_squared_error: 0.1535 - val_loss: 0.1602 - val_mean_squared_error: 0.1602
# Epoch 10/50
# 9000/9000 [==============================] - 0s 55us/sample - loss: 0.1526 - mean_squared_error: 0.1526 - val_loss: 0.1575 - val_mean_squared_error: 0.1575
# Epoch 11/50
# 9000/9000 [==============================] - 0s 53us/sample - loss: 0.1523 - mean_squared_error: 0.1523 - val_loss: 0.1553 - val_mean_squared_error: 0.1553
# Epoch 12/50
# 9000/9000 [==============================] - 1s 57us/sample - loss: 0.1494 - mean_squared_error: 0.1494 - val_loss: 0.1521 - val_mean_squared_error: 0.1521
# Epoch 13/50
# 9000/9000 [==============================] - 1s 57us/sample - loss: 0.1454 - mean_squared_error: 0.1454 - val_loss: 0.1468 - val_mean_squared_error: 0.1468
# Epoch 14/50
# 9000/9000 [==============================] - 1s 58us/sample - loss: 0.1384 - mean_squared_error: 0.1384 - val_loss: 0.1357 - val_mean_squared_error: 0.1357
# Epoch 15/50
# 9000/9000 [==============================] - 1s 58us/sample - loss: 0.1261 - mean_squared_error: 0.1261 - val_loss: 0.1337 - val_mean_squared_error: 0.1337
# Epoch 16/50
# 9000/9000 [==============================] - 1s 58us/sample - loss: 0.1176 - mean_squared_error: 0.1176 - val_loss: 0.1321 - val_mean_squared_error: 0.1321
# Epoch 17/50
# 9000/9000 [==============================] - 1s 57us/sample - loss: 0.1102 - mean_squared_error: 0.1102 - val_loss: 0.1153 - val_mean_squared_error: 0.1153
# Epoch 18/50
# 9000/9000 [==============================] - 1s 73us/sample - loss: 0.1064 - mean_squared_error: 0.1064 - val_loss: 0.1043 - val_mean_squared_error: 0.1043
# Epoch 19/50
# 9000/9000 [==============================] - 1s 74us/sample - loss: 0.0980 - mean_squared_error: 0.0980 - val_loss: 0.1025 - val_mean_squared_error: 0.1025
# Epoch 20/50
# 9000/9000 [==============================] - 1s 58us/sample - loss: 0.0916 - mean_squared_error: 0.0916 - val_loss: 0.0930 - val_mean_squared_error: 0.0930
# Epoch 21/50
# 9000/9000 [==============================] - 1s 60us/sample - loss: 0.0868 - mean_squared_error: 0.0868 - val_loss: 0.0868 - val_mean_squared_error: 0.0868
# Epoch 22/50
# 9000/9000 [==============================] - 1s 60us/sample - loss: 0.0765 - mean_squared_error: 0.0765 - val_loss: 0.0964 - val_mean_squared_error: 0.0964
# Epoch 23/50
# 9000/9000 [==============================] - 1s 60us/sample - loss: 0.0609 - mean_squared_error: 0.0609 - val_loss: 0.0603 - val_mean_squared_error: 0.0603
# Epoch 24/50
# 9000/9000 [==============================] - 1s 61us/sample - loss: 0.0522 - mean_squared_error: 0.0522 - val_loss: 0.0576 - val_mean_squared_error: 0.0576
# Epoch 25/50
# 9000/9000 [==============================] - 1s 62us/sample - loss: 0.0468 - mean_squared_error: 0.0468 - val_loss: 0.0481 - val_mean_squared_error: 0.0481
# Epoch 26/50
# 9000/9000 [==============================] - 1s 66us/sample - loss: 0.0437 - mean_squared_error: 0.0437 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
# Epoch 27/50
# 9000/9000 [==============================] - 1s 65us/sample - loss: 0.0398 - mean_squared_error: 0.0398 - val_loss: 0.0454 - val_mean_squared_error: 0.0454
# Epoch 28/50
# 9000/9000 [==============================] - 1s 60us/sample - loss: 0.0331 - mean_squared_error: 0.0331 - val_loss: 0.0337 - val_mean_squared_error: 0.0337
# Epoch 29/50
# 9000/9000 [==============================] - 1s 60us/sample - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0305 - val_mean_squared_error: 0.0305
# Epoch 30/50
# 9000/9000 [==============================] - 1s 75us/sample - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0396 - val_mean_squared_error: 0.0396
# Epoch 31/50
# 9000/9000 [==============================] - 1s 62us/sample - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 32/50
# 9000/9000 [==============================] - 1s 63us/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 33/50
# 9000/9000 [==============================] - 1s 62us/sample - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 34/50
# 9000/9000 [==============================] - 1s 62us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 35/50
# 9000/9000 [==============================] - 1s 60us/sample - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 36/50
# 9000/9000 [==============================] - 1s 68us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 37/50
# 9000/9000 [==============================] - 1s 63us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 38/50
# 9000/9000 [==============================] - 1s 58us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 39/50
# 9000/9000 [==============================] - 0s 50us/sample - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 40/50
# 9000/9000 [==============================] - 1s 56us/sample - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 41/50
# 9000/9000 [==============================] - 0s 51us/sample - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 8.4382e-04 - val_mean_squared_error: 8.4382e-04
# Epoch 42/50
# 9000/9000 [==============================] - 0s 50us/sample - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 43/50
# 9000/9000 [==============================] - 1s 63us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 44/50
# 9000/9000 [==============================] - 0s 55us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 45/50
# 9000/9000 [==============================] - 0s 56us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 46/50
# 9000/9000 [==============================] - 0s 53us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 47/50
# 9000/9000 [==============================] - 0s 52us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 48/50
# 9000/9000 [==============================] - 0s 51us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 49/50
# 9000/9000 [==============================] - 0s 48us/sample - loss: 8.9297e-04 - mean_squared_error: 8.9297e-04 - val_loss: 7.3172e-04 - val_mean_squared_error: 7.3172e-04
# Epoch 50/50
# 9000/9000 [==============================] - 0s 48us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.8846e-04 - val_mean_squared_error: 9.8846e-04

# %%
# evaluate model
print('MODEL TEST:')
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)
# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print()
print()

# evaluate model with the exact curve
print('MODEL TEST WITH THE EXACT SURFACE:')
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)
# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# MODEL TEST:
# 1000/1000 [==============================] - 0s 53us/sample - loss: 9.8846e-04 - mean_squared_error: 9.8846e-04
#
# Test loss: 0.0009884584774263203
# Test accuracy: 0.0009884585
#
#
# MODEL TEST WITH THE EXACT SURFACE:
# 1000/1000 [==============================] - 0s 52us/sample - loss: 9.8846e-04 - mean_squared_error: 9.8846e-04
#
# Test loss: 0.0009884584774263203
# Test accuracy: 0.0009884585

# %%
# Plot training & validation loss values
n = 500
x_predicted = np.zeros((n, 2))

x_predicted[:,0] = np.random.uniform(-2., 2., n)
x_predicted[:,1] = np.random.uniform(-2., 2., n)
X, Y = np.meshgrid(np.arange(-2.,2.,0.25), np.arange(-2.,2.,0.25))

y_expected = np.sin(X**2 + Y**2)
y_predicted = model.predict(x_predicted)

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')

plt.show()

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x_predicted[:,0], x_predicted[:,1], y_predicted, c='red', marker='.', label = 'Predicted')
ax.plot_surface(X, Y, y_expected, alpha = 0.3)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_zlabel('$z$')
ax.view_init(30, 45)

plt.legend()
plt.show()

# %% [markdown]
# Per cercare di migliorare i risultati ho aggiunto un layer che utlizza come attivatore 'sigmoid' e ho aumentato il numero di neuroni. Con questa scelta di parametri tuttavia viene ben fittata la superficie ma appena ci si allontana dall'intorno del training la NN non è in grado di prevedere l'andamento della funzione.
